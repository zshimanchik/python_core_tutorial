# %% [markdown]
# ### Hashable

# %%
d = {}
d[4] = 3

# %%
d = {}
d[(1,2)] = 3

# %%
d = {}
d[[1,2]] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3da71f4f2843> in <module>
#       1 d = {}
# ----> 2 d[[1,2]] = 4
#
# TypeError: unhashable type: 'list'

# %%
d = {}
a = {1:3}
d[a] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1fb3c712a08f> in <module>
#       1 d = {}
#       2 a = {1:3}
# ----> 3 d[a] = 5
#
# TypeError: unhashable type: 'dict'

# %%
# Discuss

# %%
class A:
    pass

a = A()
d = {}
d[a] = 6

# %%
class A:
    def __hash__(self):
        return 5

a1 = A()
a2 = A()
d = {}
d[a1] = 7
print(d[a2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f887ec83827f> in <module>
#       7 d = {}
#       8 d[a1] = 7
# ----> 9 print(d[a2])
#
# KeyError: <__main__.A object at 0x103d3e0d0>

# %%
class A:
    def __hash__(self):
        return 5

a1 = A()
a2 = A()
d = {}
d[a1] = 8
d[a2] = 9

print(d[a1])
# Out:
# 8

# %%
class A:
    def __hash__(self):
        return 5
    def __eq__(self, other):
        return True

a1 = A()
a2 = A()
d = {}
d[a1] = 10

print(d[a2])
# Out:
# 10
