# %%
def inspect(func):
    print(func.__name__)
    print('varnames', func.__code__.co_varnames)
    print('freevars', func.__code__.co_freevars)
    print('cellvars', func.__code__.co_cellvars)

# %%
a1 = 13
def myfunc1():
    a1 = 14
    print(a1)

inspect(myfunc1)
myfunc1()
# Out:
# myfunc1
# varnames ('a1',)
# freevars ()
# cellvars ()
# 14

# %%
a2 = 13
def myfunc2():
    b = 14 + a2
    print(b)

inspect(myfunc2)
myfunc2()
# Out:
# myfunc2
# varnames ('b',)
# freevars ()
# cellvars ()
# 27

# %%
a3 = 13
def myfunc3():
    b = 14 + a3

    a3 = 1
    print(a3)

inspect(myfunc3)
myfunc3()
# Out:
# myfunc3
# varnames ('a3', 'b')
# freevars ()
# cellvars ()
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-ca57207d7079> in <module>
#       6
#       7 inspect(myfunc3)
# ----> 8 myfunc3()
#       9
#      10
#
# <ipython-input-4-ca57207d7079> in myfunc3()
#       1 a3 = 13
#       2 def myfunc3():
# ----> 3     b = 14 + a3
#       4     a3 = 1
#       5     print(a3)
#
# UnboundLocalError: local variable 'a3' referenced before assignment

# %%
a = 13

def myfunc1(arg1):
    a = 15
    def myfunc2(arg2):
        a = 16

    inspect(myfunc2)
    myfunc2(2)

inspect(myfunc1)
myfunc1(1)
# Out:
# myfunc1
# varnames ('arg1', 'a', 'myfunc2')
# freevars ()
# cellvars ()
# myfunc2
# varnames ('arg2', 'a')
# freevars ()
# cellvars ()

# %%
from dis import dis
dis(compile('''
a = 13

def myfunc1(arg1):
    a = 15
    def myfunc2(arg2):
        a = 16

    myfunc2(2)

myfunc1(1)
''', '', 'exec'))
# Out:
#   2           0 LOAD_CONST               0 (13)
#               2 STORE_NAME               0 (a)
#
#   4           4 LOAD_CONST               1 (<code object myfunc1 at 0x1113f9450, file "", line 4>)
#               6 LOAD_CONST               2 ('myfunc1')
#               8 MAKE_FUNCTION            0
#              10 STORE_NAME               1 (myfunc1)
#
#  11          12 LOAD_NAME                1 (myfunc1)
#              14 LOAD_CONST               3 (1)
#              16 CALL_FUNCTION            1
#              18 POP_TOP
#              20 LOAD_CONST               4 (None)
#              22 RETURN_VALUE
#
# Disassembly of <code object myfunc1 at 0x1113f9450, file "", line 4>:
#   5           0 LOAD_CONST               1 (15)
#               2 STORE_FAST               1 (a)
#
#   6           4 LOAD_CONST               2 (<code object myfunc2 at 0x10f963920, file "", line 6>)
#               6 LOAD_CONST               3 ('myfunc1.<locals>.myfunc2')
#               8 MAKE_FUNCTION            0
#              10 STORE_FAST               2 (myfunc2)
#
#   9          12 LOAD_FAST                2 (myfunc2)
#              14 LOAD_CONST               4 (2)
#              16 CALL_FUNCTION            1
#              18 POP_TOP
#              20 LOAD_CONST               0 (None)
#              22 RETURN_VALUE
#
# Disassembly of <code object myfunc2 at 0x10f963920, file "", line 6>:
#   7           0 LOAD_CONST               1 (16)
#               2 STORE_FAST               1 (a)
#               4 LOAD_CONST               0 (None)
#               6 RETURN_VALUE

# %% [markdown]
# Frame object
#
# https://github.com/python/cpython/blob/cb9879b948a19c9434316f8ab6aba9c4601a8173/Include/cpython/frameobject.h#L28
#
# Function call:
#
# https://github.com/python/cpython/blob/cb9879b948a19c9434316f8ab6aba9c4601a8173/Objects/call.c#L307

# %%
a = 13

def myfunc1(arg1):
    a = 15
    def myfunc2(arg2):
        nonlocal a
        a = 16

    inspect(myfunc2)
    myfunc2(2)

inspect(myfunc1)
myfunc1(1)
# Out:
# myfunc1
# varnames ('arg1', 'myfunc2')
# freevars ()
# cellvars ('a',)
# myfunc2
# varnames ('arg2',)
# freevars ('a',)
# cellvars ()

# %%
a = 13

def myfunc1(arg1):
    a = 15
    def myfunc2(arg2):
        def myfunc3():
            nonlocal a
            a = 17
        inspect(myfunc3)
        myfunc3()

    inspect(myfunc2)
    myfunc2(2)
    print(a)

inspect(myfunc1)
myfunc1(1)
# Out:
#   File "<ipython-input-15-9502d492ecfb>", line 7
#     nonlocal a
#     ^
# SyntaxError: name 'a' is nonlocal and global

# %%
a = 13

def myfunc1(arg1):
    global a
    a = 15
    def myfunc2(arg2):
        global  a
        a = 16

        def myfunc3():
            nonlocal a
            a = 17
        inspect(myfunc3)
        myfunc3()

    inspect(myfunc2)
    myfunc2(2)
    print(a)

inspect(myfunc1)
myfunc1(1)
# Out:
#   File "<ipython-input-18-93c8de48bd02>", line 11
#     nonlocal a
#     ^
# SyntaxError: no binding for nonlocal 'a' found

# %%
a = 13

def myfunc1(arg1):
    a = 15
    def myfunc2(arg2):
        a = 16
        def myfunc3():
            nonlocal a
            a = 17
        inspect(myfunc3)
        myfunc3()


    inspect(myfunc2)
    myfunc2(2)
    print(a)

inspect(myfunc1)
myfunc1(1)
# Out:
# myfunc1
# varnames ('arg1', 'a', 'myfunc2')
# freevars ()
# cellvars ()
# myfunc2
# varnames ('arg2', 'myfunc3')
# freevars ()
# cellvars ('a',)
# myfunc3
# varnames ()
# freevars ('a',)
# cellvars ()
# 15

# %% [markdown]
# https://cpython-devguide.readthedocs.io/compiler/#ast-to-cfg-to-bytecode
#
# > variables can be classified as local, free/cell for closures, or global
